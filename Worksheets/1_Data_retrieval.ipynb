# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsferret/Code-Division/blob/main/Worksheets/1_Data_retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data retrieval
# ---
#
# Examples of data being retrieved from a range of sources

# %% [markdown]
# ## From a web page
# ---
#
# The code below reads all the data tables from the Wikipedia page on Glasgow.  The 8th table on the page shows population data over a period of centuries.
#
# The code reads the data from the page into a list of datatables.  The index [7] is used to access the 8th table in the list.  Change the index to see other data tables.  Use len(datatables) to find out how many tables are in the list.

# %%
import pandas as pd

def get_data():
  datatables = pd.read_html('https://en.wikipedia.org/wiki/Glasgow#Climate')
  #  change the line below to look at other tables, add the line print(len(datatables)) to see how many tables there are
  df = datatables[0]  #Glasgow population data
  return df



# run and test the get_data() function, test visually - does it match the data on the web page
get_data()
# Out:
#      Historical population of Glasgow and city limits  ...                                         Unnamed: 4
# 0   Historical population and city limits Year[76]...  ...                                                NaN
# 1                                            Year[76]  ...                                       Area changes
# 2                                                1300  ...                                            Initial
# 3                                                1600  ...                                            Unknown
# 4                                                1791  ...  Anderson to James Street/West Nile Street to C...
# 5                                                1831  ...                          Necropolis and Blythswood
# 6                                                1846  ...   Burghs of Anderston and Calton/Barony of Gorbals
# 7                                                1872  ...  Districts of Keppochhill, Alexandra Parade and...
# 8                                                1891  ...  Burghs of Govanhill, Crosshill, Pollokshields,...
# 9                                                1901  ...  Bellahouston Park and Craigton. Districts of B...
# 10                                               1912  ...  Burghs of Govan, Partick, Pollokshaws. Distric...
# 11                                               1921  ...                                          No change
# 12                                               1926  ...  Districts of Lambhill, Millerston, Aikenhead, ...
# 13                                               1938  ...  Districts of Balmuildy, Auchinairn, Cardowan, ...
# 14                                               1946  ...                                          No change
# 15                                               1951  ...                                          No change
# 16                                               1961  ...                                          No change
# 17                                               1971  ...                                          No change
# 18                                               1981  ...  Burghs of Rutherglen, Cambuslang, Mount Vernon...
# 19                                               1991  ...                              Minor boundary change
# 20                                               2001  ...  Rutherglen and Cambuslang transferred to South...
# 21                                               2011  ...                              Minor boundary change
#
# [22 rows x 5 columns]

# %% [markdown]
# ## From a local file
# ---
#
# You can upload from a local file using the code below.  uploaded = file.upload() will open a file chooser and you can choose the data file from there.  After that, just use the file name to read from it.
#
# The file exists while the notebook is running, so should only be uploaded once.  If you need to access again, cancel the upload.
#
# For this exercise you will need a copy of an Excel file.  To get a copy of this file "public_use-talent-migration.xlsx" go to this page: https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx and click on the Download button.  You will now have a copy in your Downloads folder.

# %%
import pandas as pd
from google.colab import files
import io

def get_data():
  # upload a set of chosen files then read a specified file
  uploaded = files.upload()
  #df = pd.read_excel(uploaded['public_use-talent-migration.xlsx'],sheet_name="Industry Migration")
  #return df
  print (uploaded)



# run and test the get_data() function, test visually - does it match the data on the web page
get_data()
# Out:
#      <input type="file" id="files-068de91c-0d8e-40af-90f5-79d47a65b5c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-068de91c-0d8e-40af-90f5-79d47a65b5c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-b983f49d678a> in <module>()
#      13
#      14 # run and test the get_data() function, test visually - does it match the data on the web page
# ---> 15 get_data()
#
# <ipython-input-3-b983f49d678a> in get_data()
#       5 def get_data():
#       6   # upload a set of chosen files then read a specified file
# ----> 7   uploaded = files.upload()
#       8   #df = pd.read_excel(uploaded['public_use-talent-migration.xlsx'],sheet_name="Industry Migration")
#       9   #return df
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      61   result = _output.eval_js(
#      62       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 63           input_id=input_id, output_id=output_id))
#      64   files = _collections.defaultdict(_six.binary_type)
#      65   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Cannot read properties of undefined (reading '_uploadFiles')

# %% [markdown]
# ## From a csv file hosted on Github.com
# ---
#
# The code below reads the data table stored in a Comma Separated Values file (this is a text file containing rows of data with each column within the row separated from the next column by a comma).
#
# If you were using Jupyter Notebooks on your device, the url could be replaced with the path to the CSV file.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/Paisley-Weather-Data.csv"
df = pd.read_csv(url)
df
# Out:
#      yyyy  mm tmax (degC)  ... rain (mm) sun (hours)       status
# 0    1959   1           4  ...      40.9        54.1          NaN
# 1    1959   2         6.6  ...      41.8        17.8          NaN
# 2    1959   3        10.6  ...      50.9        85.7          NaN
# 3    1959   4          13  ...      76.3       125.1          NaN
# 4    1959   5        18.1  ...        24         222          NaN
# ..    ...  ..         ...  ...       ...         ...          ...
# 741  2020  10       12.9*  ...    185.3*       76.8*  Provisional
# 742  2020  11       10.6*  ...    142.4*       29.3*  Provisional
# 743  2020  12        6.9*  ...    131.0*       31.6*  Provisional
# 744  2021   1        4.9*  ...    132.2*       51.0*  Provisional
# 745  2021   2        7.0*  ...    144.3*       58.8*  Provisional
#
# [746 rows x 8 columns]

# %% [markdown]
# ## From an Excel file hosted on Github.com
# ---
#
# The code below reads the data table from a sheet in an Excel file.  If you don't specify a sheet then it will assume that you want to read the data from the first sheet in the Excel workbook (sheet_name = 0).  If you don't know the sheet name but know it is the second sheet, you can use sheet_name = 1, or 2 for the third sheet, etc.
#
# If you were using Jupyter Notebooks on your device, the url could be replace with the path to the Excel file.

# %%
import pandas as pd
url = "https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true"
df = pd.read_excel(url,sheet_name="Industry Migration")

df
# Out:
#      country_code          country_name  ... net_per_10K_2018 net_per_10K_2019
# 0              ae  United Arab Emirates  ...            68.51            49.55
# 1              ae  United Arab Emirates  ...           149.57           182.22
# 2              ae  United Arab Emirates  ...           409.18           407.41
# 3              ae  United Arab Emirates  ...           236.69           188.07
# 4              ae  United Arab Emirates  ...           852.39           519.40
# ...           ...                   ...  ...              ...              ...
# 5290           zw              Zimbabwe  ...            70.60           -18.30
# 5291           zw              Zimbabwe  ...          -234.59          -304.36
# 5292           zw              Zimbabwe  ...           311.03           -55.88
# 5293           zw              Zimbabwe  ...          -108.16          -213.82
# 5294           zw              Zimbabwe  ...           -39.32           -92.51
#
# [5295 rows x 13 columns]

# %% [markdown]
# ## From an API which delivers the data in JSON format
# ---
#
# The code below requests the data from the url.  This is a bit more tricky than the other ways to get the data as how you access the data will depend on how it is organised.
#
# In this example, the data is returned as a dictionary, which will have the key 'data' against which the actual data is stored.  In the example, the data has been taken from the 'data' key/value pair and is stored in json_data.
#
# Again, in this example, the json_data is a list of json_objects but it only has one object in the list.  Try adding the line `print(json_data)` to see this.
#
# data_table is the first object in the json_data list.  Try adding the line `print(data_table)` to see this.
#
# In this example, the data table object has three keys, 'to', 'from' and 'regions'.  The 'regions' value is the data we want to use in our dataframe, so we normalize this json data into a pandas dataframe (df), which you can see as the output.
#
# Each API is likely to deliver its data in a different format and so you will need to be happy to read the documentation and to inspect the data to see what keys and indexes you need to access.
#
# For information on the format of the data, see https://carbon-intensity.github.io/api-definitions/#regional

# %%
import pandas as pd
import requests

url = "https://api.carbonintensity.org.uk/regional"
json_data = requests.get(url).json()['data']
data_table = json_data[0]
print(json_data)
df = pd.json_normalize(data_table['regions'])
df
print (data_table)
# Out:
# [{'from': '2022-02-08T10:30Z', 'to': '2022-02-08T11:00Z', 'regions': [{'regionid': 1, 'dnoregion': 'Scottish Hydro Electric Power Distribution', 'shortname': 'North Scotland', 'intensity': {'forecast': 0, 'index': 'very low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 0}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 17}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 83}]}, {'regionid': 2, 'dnoregion': 'SP Distribution', 'shortname': 'South Scotland', 'intensity': {'forecast': 5, 'index': 'very low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0.5}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 2.3}, {'fuel': 'gas', 'perc': 0.1}, {'fuel': 'nuclear', 'perc': 11.1}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 7}, {'fuel': 'solar', 'perc': 0.6}, {'fuel': 'wind', 'perc': 78.4}]}, {'regionid': 3, 'dnoregion': 'Electricity North West', 'shortname': 'North West England', 'intensity': {'forecast': 66, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 2.3}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 6.4}, {'fuel': 'gas', 'perc': 15.7}, {'fuel': 'nuclear', 'perc': 32.9}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 2.4}, {'fuel': 'solar', 'perc': 0.4}, {'fuel': 'wind', 'perc': 39.9}]}, {'regionid': 4, 'dnoregion': 'NPG North East', 'shortname': 'North East England', 'intensity': {'forecast': 12, 'index': 'very low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 8}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 31.1}, {'fuel': 'gas', 'perc': 0}, {'fuel': 'nuclear', 'perc': 36.2}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 1.8}, {'fuel': 'solar', 'perc': 0.5}, {'fuel': 'wind', 'perc': 22.5}]}, {'regionid': 5, 'dnoregion': 'NPG Yorkshire', 'shortname': 'Yorkshire', 'intensity': {'forecast': 119, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 37.6}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 3.8}, {'fuel': 'gas', 'perc': 18.8}, {'fuel': 'nuclear', 'perc': 4.5}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0.2}, {'fuel': 'solar', 'perc': 0.2}, {'fuel': 'wind', 'perc': 34.8}]}, {'regionid': 6, 'dnoregion': 'SP Manweb', 'shortname': 'North Wales & Merseyside', 'intensity': {'forecast': 63, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0.7}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 2.2}, {'fuel': 'gas', 'perc': 15.3}, {'fuel': 'nuclear', 'perc': 11.4}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 4.4}, {'fuel': 'solar', 'perc': 1.5}, {'fuel': 'wind', 'perc': 64.4}]}, {'regionid': 7, 'dnoregion': 'WPD South Wales', 'shortname': 'South Wales', 'intensity': {'forecast': 326, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 82.8}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 1.9}, {'fuel': 'wind', 'perc': 15.4}]}, {'regionid': 8, 'dnoregion': 'WPD West Midlands', 'shortname': 'West Midlands', 'intensity': {'forecast': 192, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 2.9}, {'fuel': 'coal', 'perc': 3.1}, {'fuel': 'imports', 'perc': 2.5}, {'fuel': 'gas', 'perc': 40.1}, {'fuel': 'nuclear', 'perc': 12.6}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 1.6}, {'fuel': 'solar', 'perc': 2.2}, {'fuel': 'wind', 'perc': 34.9}]}, {'regionid': 9, 'dnoregion': 'WPD East Midlands', 'shortname': 'East Midlands', 'intensity': {'forecast': 329, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 9.8}, {'fuel': 'coal', 'perc': 14.6}, {'fuel': 'imports', 'perc': 1}, {'fuel': 'gas', 'perc': 45.8}, {'fuel': 'nuclear', 'perc': 1.2}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0.1}, {'fuel': 'solar', 'perc': 1.7}, {'fuel' ...
#     regionid  ... intensity.index
# 0          1  ...        very low
# 1          2  ...        very low
# 2          3  ...             low
# 3          4  ...        very low
# 4          5  ...             low
# 5          6  ...             low
# 6          7  ...       very high
# 7          8  ...        moderate
# 8          9  ...       very high
# 9         10  ...             low
# 10        11  ...        very low
# 11        12  ...            high
# 12        13  ...             low
# 13        14  ...        moderate
# 14        15  ...        moderate
# 15        16  ...        very low
# 16        17  ...            high
# 17        18  ...        moderate
#
# [18 rows x 6 columns]

# %% [markdown]
# ### Exercise - upload a file from your local drive
#
# Visit the Kent and Medway Air Quality site: https://kentair.org.uk/
#
# Collect a data file containing data on Ozone levels in Dover:
#
# Open the site
# Go to the Data page
# Launch the data selector tool
# Select:
# *  Automatic monitoring data
# *  Measurement data and simple statistics
# *  Ozone
# *  Daily mean
# *  This month
# *  Thurrock
# *  Thurrock
#
# Click on Download CSV
#
# This should be downloaded into your Downloads folder.
#
# NOW
#
# Write a function that will allow you to upload the file and then read its contents into a dataframe.
#
# To read an uploaded CSV file (which will be in bytes format) use:
#
# ```
# df = pd.read_csv(io.BytesIO(uploaded['your filename']))
# ```
#
#
# Display the dataframe and compare the contents with the output on the site you took the data from.

# %%
import pandas as pd
from google.colab import files
import io

def get_data():
  # upload a set of chosen files then read a specified file
  # !rm NO2-daily-mean-2014-2021-Swale-Newington.csv
  uploaded = files.upload()
  df = pd.read_csv(io.BytesIO(uploaded['NO2-daily-mean-2014-2021-Swale-Newington.csv']))
  return df

get_data()

# %% [markdown]
# # ACTIVITIES
#
# RUN ALL THE CODE CELLS ABOVE TO SEE WHAT THEY DO AND WHAT DATA THEY GET FOR YOU.
#
# Now have a go at opening a few data sets yourself.
#
# ### Exercise 1
# ---
#
# *  Open the datasets list: [here](https://docs.google.com/document/d/1cijDOCDixsYu-Rr9pC8STPPXado3xoFpgBAZgdDTLHs/edit?usp=sharing)
#
# *  Find a dataset that is a CSV file, copy the code above (for online CSV) into the code cell below
#
# *  Run the code to open the data.

# %%
import pandas as pd
from google.colab import files
import io

def get_data():
  # upload a set of chosen files then read a specified file
  # !rm working-with-data/main/Data%20sets/page_views.csv
  uploaded = files.upload()
  df = pd.read_csv(io.BytesIO(uploaded['working-with-data/main/Data%20sets/page_views.csv']))
  return df

get_data()
# Out:
# rm: cannot remove 'NO2-daily-mean-2014-2021-Swale-Newington.csv': No such file or directory
#      <input type="file" id="files-8eafa837-2a3f-4132-89ba-03e38df2c9f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8eafa837-2a3f-4132-89ba-03e38df2c9f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-c15760192aa6> in <module>()
#      10   return df
#      11
# ---> 12 get_data()
#
# <ipython-input-4-c15760192aa6> in get_data()
#       6   # upload a set of chosen files then read a specified file
#       7   get_ipython().system('rm NO2-daily-mean-2014-2021-Swale-Newington.csv')
# ----> 8   uploaded = files.upload()
#       9   df = pd.read_csv(io.BytesIO(uploaded['working-with-data/main/Data%20sets/page_views.csv']))
#      10   return df
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      61   result = _output.eval_js(
#      62       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 63           input_id=input_id, output_id=output_id))
#      64   files = _collections.defaultdict(_six.binary_type)
#      65   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Cannot read properties of undefined (reading '_uploadFiles')

# %% [markdown]
# ### Exercise 2
# ---
# Open the datasets list: [here](https://docs.google.com/document/d/1cijDOCDixsYu-Rr9pC8STPPXado3xoFpgBAZgdDTLHs/edit?usp=sharing)
#
# * Find a dataset that is an Excel file
# * Copy the code above (for Excel files on Github) into the code cell below
# * Change the line
# ```
# df = pd.read_excel(url,sheet_name="Industry Migration")
# ```
# to
# ```
# df = pd.read_excel(url)
# ```
# This will then open the first sheet in the Excel file, rather than a named sheet.
#
# * Run the code to open the data.

# %%
import pandas as pd
url = "https://github.com/futureCodersSE/working-with-data/blob/main/Happiness-Data/2015.xlsx?raw=true"
df = pd.read_excel(url)

df
# Out:
#          Country  ... Dystopia Residual
# 0    Switzerland  ...           2.51738
# 1        Iceland  ...           2.70201
# 2        Denmark  ...           2.49204
# 3         Norway  ...           2.46531
# 4         Canada  ...           2.45176
# ..           ...  ...               ...
# 153       Rwanda  ...           0.67042
# 154        Benin  ...           1.63328
# 155        Syria  ...           0.32858
# 156      Burundi  ...           1.83302
# 157         Togo  ...           1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# ### Exercise 3
# ---
# *  Copy the code from the API delivered in JSON format
# *  Change the URL to add /england to the end of it
# *  Run the code to see the data for England only
# *  Change it again to show data for Scotland, (/scotland)
# *  Change it again to show data for Wales

# %%
import pandas as pd
import requests

url = "https://api.carbonintensity.org.uk/regional/england"
json_data = requests.get(url).json()['data']
data_table = json_data[0]
print(json_data)
df = pd.json_normalize(data_table['data'])
df
print (data_table)
# Out:
# [{'regionid': 15, 'dnoregion': 'England', 'shortname': 'England', 'data': [{'from': '2022-02-08T11:30Z', 'to': '2022-02-08T12:00Z', 'intensity': {'forecast': 154, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 6.8}, {'fuel': 'coal', 'perc': 2.7}, {'fuel': 'imports', 'perc': 8.1}, {'fuel': 'gas', 'perc': 27.4}, {'fuel': 'nuclear', 'perc': 15.3}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 1}, {'fuel': 'solar', 'perc': 6.1}, {'fuel': 'wind', 'perc': 32.6}]}]}]
# {'regionid': 15, 'dnoregion': 'England', 'shortname': 'England', 'data': [{'from': '2022-02-08T11:30Z', 'to': '2022-02-08T12:00Z', 'intensity': {'forecast': 154, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 6.8}, {'fuel': 'coal', 'perc': 2.7}, {'fuel': 'imports', 'perc': 8.1}, {'fuel': 'gas', 'perc': 27.4}, {'fuel': 'nuclear', 'perc': 15.3}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 1}, {'fuel': 'solar', 'perc': 6.1}, {'fuel': 'wind', 'perc': 32.6}]}]}
